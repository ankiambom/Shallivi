# %%
# Here i have import my libarary
import pandas as pd

#Loading of data set
df = pd.read_csv("Skills Information.csv")
df.head(15)
# Out:
#                       Timestamp                          Full Name   \
# 0   2025/06/30 8:36:06 PM GMT+3     Ankiambom Melchisedech Awosang
# 1   2025/06/30 8:43:03 PM GMT+3                    Teneng Emmanuela
# 2   2025/07/04 9:29:38 AM GMT+3                                 NaN
# 3   2025/07/04 1:43:08 PM GMT+3                                 NaN
# 4   2025/07/07 9:29:02 PM GMT+3  REYHAN EBAI ENOWNJOCK OJONG KUKAH
# 5  2025/07/09 10:49:37 PM GMT+3         Kongnyuy Pierette Nyuykonge
# 6  2025/07/09 11:12:37 PM GMT+3                    Tiayah Patience
# 7  2025/07/09 11:15:24 PM GMT+3                    MUHAMMADU BELLO
#
#   What is your availability per week (in hours)?    \
# 0                                               5h
# 1                                               2h
# 2                                                8
# 3                                               2h
# 4                                               5h
# ...

# %%
#checking the related information with the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 10 columns):
#  #   Column                                                                               Non-Null Count  Dtype
# ---  ------                                                                               --------------  -----
#  0   Timestamp                                                                            8 non-null      object
#  1   Full Name                                                                            6 non-null      object
#  2   What is your availability per week (in hours)?                                       8 non-null      object
#  3   Which programming languages do you feel most comfortable with?                       8 non-null      object
#  4   Rate your proficiency in AI/ Machine learning (scikit-learn, TensorFlow, etc.)       8 non-null      int64
# ...

# %%
df.isna().sum()
# Out:
# Timestamp                                                                              0
# Full Name                                                                              2
# What is your availability per week (in hours)?                                         0
# Which programming languages do you feel most comfortable with?                         0
# Rate your proficiency in AI/ Machine learning (scikit-learn, TensorFlow, etc.)         0
# Rate your proficiency in Data analysis (Pandas, NumPy, etc.)                           0
# Rate your proficiency in Network security /  Ethical hacking / penetration testing     0
# Rate your proficiency in  Design UX / Graphics                                         0
# Which domain(s) are you interested ?                                                   0
# Do you have any particular strengths or areas you'd like to develop more?              0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 2

# %%
# give a summary of the dataset
df.describe()
# Out:
#        Rate your proficiency in AI/ Machine learning (scikit-learn, TensorFlow, etc.)      \
# count                                           8.000000
# mean                                            2.000000
# std                                             1.414214
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.500000
# 75%                                             2.250000
# max                                             5.000000
#
#        Rate your proficiency in Data analysis (Pandas, NumPy, etc.)   \
# count                                           8.000000
# mean                                            2.625000
# std                                             2.065879
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.500000
# ...

# %%
df.shape
# Out:
# (8, 10)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Full Name ',
#        'What is your availability per week (in hours)?  ',
#        'Which programming languages do you feel most comfortable with?  ',
#        'Rate your proficiency in AI/ Machine learning (scikit-learn, TensorFlow, etc.)    ',
#        'Rate your proficiency in Data analysis (Pandas, NumPy, etc.) ',
#        'Rate your proficiency in Network security /  Ethical hacking / penetration testing ',
#        'Rate your proficiency in  Design UX / Graphics',
#        'Which domain(s) are you interested ?  ',
#        'Do you have any particular strengths or areas you'd like to develop more?  '],
#       dtype='object')

# %%
#checking for missing values 
df.isnull().sum()
# Out:
# Timestamp                                                                              0
# Full Name                                                                              2
# What is your availability per week (in hours)?                                         0
# Which programming languages do you feel most comfortable with?                         0
# Rate your proficiency in AI/ Machine learning (scikit-learn, TensorFlow, etc.)         0
# Rate your proficiency in Data analysis (Pandas, NumPy, etc.)                           0
# Rate your proficiency in Network security /  Ethical hacking / penetration testing     0
# Rate your proficiency in  Design UX / Graphics                                         0
# Which domain(s) are you interested ?                                                   0
# Do you have any particular strengths or areas you'd like to develop more?              0
# dtype: int64

# %%
# this will drop the rows with missing values 
df.dropna(inplace=True)

# %%
df.head(15)
# Out:
#                       Timestamp                          Full Name   \
# 0   2025/06/30 8:36:06 PM GMT+3     Ankiambom Melchisedech Awosang
# 1   2025/06/30 8:43:03 PM GMT+3                    Teneng Emmanuela
# 4   2025/07/07 9:29:02 PM GMT+3  REYHAN EBAI ENOWNJOCK OJONG KUKAH
# 5  2025/07/09 10:49:37 PM GMT+3         Kongnyuy Pierette Nyuykonge
# 6  2025/07/09 11:12:37 PM GMT+3                    Tiayah Patience
# 7  2025/07/09 11:15:24 PM GMT+3                    MUHAMMADU BELLO
#
#   What is your availability per week (in hours)?    \
# 0                                               5h
# 1                                               2h
# 4                                               5h
# 5                                               5h
# 6                                               2h
# 7                                               3h
#
#   Which programming languages do you feel most comfortable with?    \
# 0                         Python;React (Java Script)
# ...

# %%
#this will check to see if the are missing colmns and drop them
df.dropna(axis=1, inplace=True)

# %%
df.head(15)
# Out:
#                       Timestamp                          Full Name   \
# 0   2025/06/30 8:36:06 PM GMT+3     Ankiambom Melchisedech Awosang
# 1   2025/06/30 8:43:03 PM GMT+3                    Teneng Emmanuela
# 4   2025/07/07 9:29:02 PM GMT+3  REYHAN EBAI ENOWNJOCK OJONG KUKAH
# 5  2025/07/09 10:49:37 PM GMT+3         Kongnyuy Pierette Nyuykonge
# 6  2025/07/09 11:12:37 PM GMT+3                    Tiayah Patience
# 7  2025/07/09 11:15:24 PM GMT+3                    MUHAMMADU BELLO
#
#   What is your availability per week (in hours)?    \
# 0                                               5h
# 1                                               2h
# 4                                               5h
# 5                                               5h
# 6                                               2h
# 7                                               3h
#
#   Which programming languages do you feel most comfortable with?    \
# 0                         Python;React (Java Script)
# ...

# %%
df = pd.read_csv("Skills Information.csv")
df.head(15)
# Out:
#                       Timestamp                          Full Name   \
# 0   2025/06/30 8:36:06 PM GMT+3     Ankiambom Melchisedech Awosang
# 1   2025/06/30 8:43:03 PM GMT+3                    Teneng Emmanuela
# 2   2025/07/04 9:29:38 AM GMT+3                                 NaN
# 3   2025/07/04 1:43:08 PM GMT+3                                 NaN
# 4   2025/07/07 9:29:02 PM GMT+3  REYHAN EBAI ENOWNJOCK OJONG KUKAH
# 5  2025/07/09 10:49:37 PM GMT+3         Kongnyuy Pierette Nyuykonge
# 6  2025/07/09 11:12:37 PM GMT+3                    Tiayah Patience
# 7  2025/07/09 11:15:24 PM GMT+3                    MUHAMMADU BELLO
#
#   What is your availability per week (in hours)?    \
# 0                                               5h
# 1                                               2h
# 2                                                8
# 3                                               2h
# 4                                               5h
# ...

# %%
df.head(15)
# Out:
#                       Timestamp                          Full Name   \
# 0   2025/06/30 8:36:06 PM GMT+3     Ankiambom Melchisedech Awosang
# 1   2025/06/30 8:43:03 PM GMT+3                    Teneng Emmanuela
# 2   2025/07/04 9:29:38 AM GMT+3                                 NaN
# 3   2025/07/04 1:43:08 PM GMT+3                                 NaN
# 4   2025/07/07 9:29:02 PM GMT+3  REYHAN EBAI ENOWNJOCK OJONG KUKAH
# 5  2025/07/09 10:49:37 PM GMT+3         Kongnyuy Pierette Nyuykonge
# 6  2025/07/09 11:12:37 PM GMT+3                    Tiayah Patience
# 7  2025/07/09 11:15:24 PM GMT+3                    MUHAMMADU BELLO
#
#   What is your availability per week (in hours)?    \
# 0                                               5h
# 1                                               2h
# 2                                                8
# 3                                               2h
# 4                                               5h
# ...

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.head(8)
# Out:
#                       Timestamp                          Full Name   \
# 0   2025/06/30 8:36:06 PM GMT+3     Ankiambom Melchisedech Awosang
# 1   2025/06/30 8:43:03 PM GMT+3                    Teneng Emmanuela
# 2   2025/07/04 9:29:38 AM GMT+3                                 NaN
# 3   2025/07/04 1:43:08 PM GMT+3                                 NaN
# 4   2025/07/07 9:29:02 PM GMT+3  REYHAN EBAI ENOWNJOCK OJONG KUKAH
# 5  2025/07/09 10:49:37 PM GMT+3         Kongnyuy Pierette Nyuykonge
# 6  2025/07/09 11:12:37 PM GMT+3                    Tiayah Patience
# 7  2025/07/09 11:15:24 PM GMT+3                    MUHAMMADU BELLO
#
#   What is your availability per week (in hours)?    \
# 0                                               5h
# 1                                               2h
# 2                                                8
# 3                                               2h
# 4                                               5h
# ...

# %%
# if you check from the dataset up you will see that i have change Timestamp to current date 
df.rename(columns={'Timestamp': 'Current-Date'}, inplace=True)

# %%
df.head(8)
# Out:
#                    Current-Date                          Full Name   \
# 0   2025/06/30 8:36:06 PM GMT+3     Ankiambom Melchisedech Awosang
# 1   2025/06/30 8:43:03 PM GMT+3                    Teneng Emmanuela
# 2   2025/07/04 9:29:38 AM GMT+3                                 NaN
# 3   2025/07/04 1:43:08 PM GMT+3                                 NaN
# 4   2025/07/07 9:29:02 PM GMT+3  REYHAN EBAI ENOWNJOCK OJONG KUKAH
# 5  2025/07/09 10:49:37 PM GMT+3         Kongnyuy Pierette Nyuykonge
# 6  2025/07/09 11:12:37 PM GMT+3                    Tiayah Patience
# 7  2025/07/09 11:15:24 PM GMT+3                    MUHAMMADU BELLO
#
#   What is your availability per week (in hours)?    \
# 0                                               5h
# 1                                               2h
# 2                                                8
# 3                                               2h
# 4                                               5h
# ...

# %%
# Here this line of code will change the format of the date 
df['Current-Date'] = pd.to_datetime(df['Current-Date'])

# %%
df.head(8)
# Out:
#                Current-Date                          Full Name   \
# 0 2025-06-30 20:36:06-03:00     Ankiambom Melchisedech Awosang
# 1 2025-06-30 20:43:03-03:00                    Teneng Emmanuela
# 2 2025-07-04 09:29:38-03:00                                 NaN
# 3 2025-07-04 13:43:08-03:00                                 NaN
# 4 2025-07-07 21:29:02-03:00  REYHAN EBAI ENOWNJOCK OJONG KUKAH
# 5 2025-07-09 22:49:37-03:00         Kongnyuy Pierette Nyuykonge
# 6 2025-07-09 23:12:37-03:00                    Tiayah Patience
# 7 2025-07-09 23:15:24-03:00                    MUHAMMADU BELLO
#
#   What is your availability per week (in hours)?    \
# 0                                               5h
# 1                                               2h
# 2                                                8
# 3                                               2h
# 4                                               5h
# 5                                               5h
# ...

# %%
#this will drop Full name bc column
df.dropna(axis=1, inplace=True)

# %%
df.head(8)
# Out:
#                Current-Date What is your availability per week (in hours)?    \
# 0 2025-06-30 20:36:06-03:00                                               5h
# 1 2025-06-30 20:43:03-03:00                                               2h
# 2 2025-07-04 09:29:38-03:00                                                8
# 3 2025-07-04 13:43:08-03:00                                               2h
# 4 2025-07-07 21:29:02-03:00                                               5h
# 5 2025-07-09 22:49:37-03:00                                               5h
# 6 2025-07-09 23:12:37-03:00                                               2h
# 7 2025-07-09 23:15:24-03:00                                               3h
#
#   Which programming languages do you feel most comfortable with?    \
# 0                         Python;React (Java Script)
# 1                                React (Java Script)
# 2                                                  R
# ...

# %%
df.to_csv("cleaned_data.csv", index=False)

# %%
df.head(8)
# Out:
#                Current-Date What is your availability per week (in hours)?    \
# 0 2025-06-30 20:36:06-03:00                                               5h
# 1 2025-06-30 20:43:03-03:00                                               2h
# 2 2025-07-04 09:29:38-03:00                                                8
# 3 2025-07-04 13:43:08-03:00                                               2h
# 4 2025-07-07 21:29:02-03:00                                               5h
# 5 2025-07-09 22:49:37-03:00                                               5h
# 6 2025-07-09 23:12:37-03:00                                               2h
# 7 2025-07-09 23:15:24-03:00                                               3h
#
#   Which programming languages do you feel most comfortable with?    \
# 0                         Python;React (Java Script)
# 1                                React (Java Script)
# 2                                                  R
# ...

# %%
df.rename(columns={
    'What is your availability per week (in hours)?': 'Ourly Works',
}, inplace=True)

# %%
df.head(8)
# Out:
#                       Timestamp                          Full Name   \
# 0   2025/06/30 8:36:06 PM GMT+3     Ankiambom Melchisedech Awosang
# 1   2025/06/30 8:43:03 PM GMT+3                    Teneng Emmanuela
# 2   2025/07/04 9:29:38 AM GMT+3                                 NaN
# 3   2025/07/04 1:43:08 PM GMT+3                                 NaN
# 4   2025/07/07 9:29:02 PM GMT+3  REYHAN EBAI ENOWNJOCK OJONG KUKAH
# 5  2025/07/09 10:49:37 PM GMT+3         Kongnyuy Pierette Nyuykonge
# 6  2025/07/09 11:12:37 PM GMT+3                    Tiayah Patience
# 7  2025/07/09 11:15:24 PM GMT+3                    MUHAMMADU BELLO
#
#   What is your availability per week (in hours)?    \
# 0                                               5h
# 1                                               2h
# 2                                                8
# 3                                               2h
# 4                                               5h
# ...

# %%
import pandas as pd

# Example: rename a few columns
df.rename(columns={
    'Timestamp': 'Current-Date',
}, inplace=True)

# %%
df.head()
# Out:
#                 Current-Date What is your availability per week (in hours)?    \
# 0  2025-06-30 20:36:06-03:00                                               5h
# 1  2025-06-30 20:43:03-03:00                                               2h
# 2  2025-07-04 09:29:38-03:00                                                8
# 3  2025-07-04 13:43:08-03:00                                               2h
# 4  2025-07-07 21:29:02-03:00                                               5h
#
#   Which programming languages do you feel most comfortable with?    \
# 0                         Python;React (Java Script)
# 1                                React (Java Script)
# 2                                                  R
# 3                                                  R
# 4                                             Python
#
#    Rate your proficiency in AI/ Machine learning (scikit-learn, TensorFlow, etc.)      \
# 0                                                  3
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        Rate your proficiency in AI/ Machine learning (scikit-learn, TensorFlow, etc.)      \
# count                                           8.000000
# mean                                            2.000000
# std                                             1.414214
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.500000
# 75%                                             2.250000
# max                                             5.000000
#
#        Rate your proficiency in Data analysis (Pandas, NumPy, etc.)   \
# count                                           8.000000
# mean                                            2.625000
# std                                             2.065879
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.500000
# ...

# %%
numeric = df.select_dtypes(include = ["number"])

# %%
#this checks for correlation
numeric.corr()
# Out:
#                                                     Rate your proficiency in AI/ Machine learning (scikit-learn, TensorFlow, etc.)      \
# Rate your proficiency in AI/ Machine learning (...                                           1.000000
# Rate your proficiency in Data analysis (Pandas,...                                           0.880146
# Rate your proficiency in Network security /  Et...                                           0.094491
# Rate your proficiency in  Design UX / Graphics                                              -0.179425
#
#                                                     Rate your proficiency in Data analysis (Pandas, NumPy, etc.)   \
# Rate your proficiency in AI/ Machine learning (...                                           0.880146
# Rate your proficiency in Data analysis (Pandas,...                                           1.000000
# Rate your proficiency in Network security /  Et...                                          -0.032342
# ...

# %%
# working with the correlation 
# 1 means strongly positively correlated and -1 means strongly negative correlated
